# %% [markdown]
# <a href="https://colab.research.google.com/github/hebaashraf21/KNN_K-means_PCA_CUDA_Implementation/blob/main/knn/knn_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
def knn_without_cuda(reference_points, query_points, k):
    results = []
    for query_point in query_points:
        distances = np.linalg.norm(reference_points - query_point, axis=1)
        nearest_indices = np.argsort(distances)[:k]
        results.append(nearest_indices)
    return results

# %%
# Function to measure time for non-CUDA implementation
def measure_time(reference_size, query_size, k,dim):
    reference_points = np.random.rand(reference_size, dim)
    query_points = np.random.rand(query_size, dim)
    start_time = time.time()
    knn_without_cuda(reference_points, query_points, k)
    end_time = time.time()
    return end_time - start_time

# %%
# Define different sizes for reference and query points
sizes = [100, 1000, 10000, 50000, 100000,1000000]
times = []

# Measure time for each size
for size in sizes:
    time_taken = measure_time(size, 1000, 5,3)
    times.append(time_taken)
    print(f"Time taken with reference size {size}: {time_taken:.4f} seconds")

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, marker='o')
plt.title('KNN Without CUDA: Time vs Data Size')
plt.xlabel('Data Size')
plt.ylabel('Time (seconds)')
plt.grid(True)
plt.show()
# Out:
# Time taken with reference size 100: 0.0210 seconds
# Time taken with reference size 1000: 0.1030 seconds
# Time taken with reference size 10000: 1.2297 seconds
# Time taken with reference size 50000: 7.4251 seconds
# Time taken with reference size 100000: 15.8074 seconds
# Time taken with reference size 1000000: 193.7431 seconds

# %%
# Define different sizes for reference.
sizes = [100, 1000, 10000, 50000, 100000, 1000000]
k_values = [5, 7,17,111,231]
dim = 3

for k in k_values:
    times = []
    for size in sizes:
        time_taken = measure_time(size, 1000, k, dim)
        times.append(time_taken)
        print(f"Time taken with reference size {size} and k={k}: {time_taken:.4f} seconds")

    # Plot the results
    plt.figure(figsize=(10, 6))
    plt.plot(sizes, times, marker='o', label=f'k={k}')
    plt.title(f'KNN Without CUDA: Time vs Data Size for k={k}')
    plt.xlabel('Data Size')
    plt.ylabel('Time (seconds)')
    plt.grid(True)
    plt.legend()
    plt.show()
# Out:
# Time taken with reference size 100 and k=5: 0.0237 seconds
# Time taken with reference size 1000 and k=5: 0.1097 seconds
# Time taken with reference size 10000 and k=5: 1.5092 seconds
# Time taken with reference size 50000 and k=5: 12.9244 seconds
# Time taken with reference size 100000 and k=5: 17.4256 seconds
# Time taken with reference size 1000000 and k=5: 197.4030 seconds
# Time taken with reference size 100 and k=7: 0.0371 seconds
# Time taken with reference size 1000 and k=7: 0.1389 seconds
# Time taken with reference size 10000 and k=7: 1.5417 seconds
# Time taken with reference size 50000 and k=7: 7.0162 seconds
# Time taken with reference size 100000 and k=7: 16.3901 seconds
# Time taken with reference size 1000000 and k=7: 192.1791 seconds
# Time taken with reference size 100 and k=17: 0.0246 seconds
# Time taken with reference size 1000 and k=17: 0.1024 seconds
# Time taken with reference size 10000 and k=17: 1.2030 seconds
# Time taken with reference size 50000 and k=17: 7.6146 seconds
# Time taken with reference size 100000 and k=17: 15.6029 seconds
# Time taken with reference size 1000000 and k=17: 194.1888 seconds
# Time taken with reference size 100 and k=111: 0.0244 seconds
# Time taken with reference size 1000 and k=111: 0.1031 seconds
# Time taken with reference size 10000 and k=111: 1.2110 seconds
# Time taken with reference size 50000 and k=111: 7.5924 seconds
# Time taken with reference size 100000 and k=111: 15.4939 seconds
# Time taken with reference size 1000000 and k=111: 192.6280 seconds
# Time taken with reference size 100 and k=231: 0.0253 seconds
# Time taken with reference size 1000 and k=231: 0.1038 seconds
# Time taken with reference size 10000 and k=231: 1.2146 seconds
# Time taken with reference size 50000 and k=231: 7.0225 seconds
# Time taken with reference size 100000 and k=231: 16.0406 seconds
# Time taken with reference size 1000000 and k=231: 192.7724 seconds
